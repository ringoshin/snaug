# %%
# %load_ext autoreload
# %autoreload 2

# %%
# for Google Colab only: Mount my Google Drive
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# /gdrive

# %%
pwd
# Out:
# '/gdrive'

# %%
# for Google Colab only: Navigate to my snaug project folder
cd 'My Drive/Colab Notebooks/snaug'
# Out:
# /gdrive/My Drive/Colab Notebooks/snaug

# %%
# peek at current system Path settings
import sys
sys.path
# Out:
# ['',
#  '/env/python',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
# let's add my project path so that I can load my custom written
# library functions saved in '/lib' 
sys.path.append("/gdrive/My Drive/Colab Notebooks/snaug")
sys.path
# Out:
# ['',
#  '/env/python',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/gdrive/My Drive/Colab Notebooks/snaug']

# %%
#
# Load trained preferred model to generate new text and visualize it
#

from random import randint
import textwrap

from keras.models import load_model

from lib.data_common import load_doc, prepare_text_tokens
from lib.data_common import pathfinder_textfile, fixed_length_token_textfile
from lib.data_common import generate_seq_of_words
from lib.text_viz_common import init_text_viz_params, visualize_gen_text

# %%
def generate_and_visualize(lines, textgen_model, tokenizer, seq_length,
                            nlp, matcher, entity_names, entity_labels,
                            text_input='random'):
    """
    generate new text using seed text based on:
        1. user input seeding text, or
        2. randomly selected from source text, when user chooses 'random' instead
    """
    n_words = 75
    temperature = 1.22

    # select a seed text
    seed_text = lines[randint(0,len(lines))] if text_input=='random' else text_input

    # print('> using word tokenisation and pre-trained model')
    # print('> seed text:')
    # print(textwrap.fill('%s' % (seed_text), 80) + '\n')

    # generate new text using selected seed text with a temperature of 1.22
    # for higher degree of randomness
    generated = generate_seq_of_words(textgen_model, tokenizer, seq_length, 
                        seed_text, n_words, temperature)
    
    #print(seed_text)
    full_generated_text = ' '.join(['['+seed_text+']', generated])

    # output visualized text via spaCy library functions, that highlight named entities
    # pertaining to input files of Pathfinder tales
    visualize_gen_text(full_generated_text, nlp, matcher, entity_names, entity_labels, using_notebook=True)

# %%
# load fixed-length lines of tokens
doc = load_doc(fixed_length_token_textfile)
lines = doc.split('\n')
#print('Total lines: %d' % len(lines))

# %%
# tokenize and separate into features and target
X, y, seq_length, vocab_size, tokenizer = prepare_text_tokens(lines)

# %%
# load Word2vec pre-trained model
textgen_model = load_model('./model/pathfinder_wordtoken_w2v_model_50_epoch_noncuda_model.h5')
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:310: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en_core_web_lg==2.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.1.0/en_core_web_lg-2.1.0.tar.gz (826.9MB)
#      |████████████████████████████████| 826.9MB 6.0MB/s
# Building wheels for collected packages: en-core-web-lg
#   Building wheel for en-core-web-lg (setup.py) ... done
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-2.1.0-cp36-none-any.whl size=828255076 sha256=17766f09ec907bd8aeae23585e8a02f7dfb4eb75a98916ee5f9ae5e5130a78a9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fys4atwi/wheels/b4/d7/70/426d313a459f82ed5e06cc36a50e2bb2f0ec5cb31d8e0bdf09
# Successfully built en-core-web-lg
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-2.1.0
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')

# %%
# initialize text visualization parameters
nlp, matcher, entity_names, entity_labels = init_text_viz_params()

# %%
# Generate new random text as you hit <Enter> each time,
# or using your input as the seeding text to generate new random text.
# To exit the program, just type 'quit' (without the quotes) and enter.
#
text_input='random'
while True:
    text_input = input("Enter seeding text or hit <ENTER> to automate or 'quit' to exit: ")
    if text_input=='quit':
        break
    else:
        if text_input=='':
            text_input='random'
        generate_and_visualize(lines, textgen_model, tokenizer, seq_length,
                        nlp, matcher, entity_names, entity_labels,
                        text_input=text_input)
# Out:
# Enter seeding text or hit <ENTER> to automate or 'quit' to exit:
# /gdrive/My Drive/Colab Notebooks/snaug/lib/data_common.py:143: RuntimeWarning: divide by zero encountered in log
#   preds = np.log(preds) / temperature
# -----------------------------------------------------------------------------------------------
# Snaug_bot:
# <div class="entities" style="line-height: 2.5; direction: ltr">[well polished but the room is marred by signs of a recent scuffle books have been pulled down and thrown to the floor papers are scattered and in the summoning circle near a polished mahogany lectern lies the crumpled form of an elderly human female she lies face up dressed in] a trove of rune covered robes the eyes look out toward the walkway taking no note of the decay or gaze intent on something beyond rising from leaving dives home of
# <mark class="entity" style="background: pink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Sandpoint
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  and let the incident along the disturbances to
# <mark class="entity" style="background: pink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Galduria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  the adventurers eggs to the shocked gasps of the gathered guests after a stunned silence she shouts for the guards any pc succeeding at a dc perception check notices Savasha palming the plum sized</div>
# Notables:
#    LOC(s)	: Sandpoint, Galduria
#    PER(s)	: Savasha
# -----------------------------------------------------------------------------------------------
#
#
# Enter seeding text or hit <ENTER> to automate or 'quit' to exit:
#
# -----------------------------------------------------------------------------------------------
# Snaug_bot:
# <div class="entities" style="line-height: 2.5; direction: ltr">[return with the codex and hopefully find out what the professor is up to as it turns out the venture captain was right to worry rival
# <mark class="entity" style="background: #aef5ef; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Gorbic Salmore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  learned of her duplicity and sought the codex for himself with little time to prepare he dispatched
# <mark class="entity" style="background: #58f549; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Cheh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MOB</span>
# </mark>
#  a captive mimic to subdue] Montrovale in her private classroom and retrieve the book from her Salmore warned the mimic that pathfinders might be on the road form of its admiration academy this alerts and sneak gp each with a better opportunity or damage it on the table the
# <mark class="entity" style="background: #58f549; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     elemental
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MOB</span>
# </mark>
#  is alerted to the presence of the pcs see area nobody is surprised there is no surprise round and combat happens normally if the pcs surprised the
# <mark class="entity" style="background: #58f549; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     elemental
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MOB</span>
# </mark>
#  this combat</div>
# Notables:
#    PER(s)	: Gorbic Salmore, Montrovale
#    MOB(s)	: Cheh, elemental
# -----------------------------------------------------------------------------------------------
#
#
# Enter seeding text or hit <ENTER> to automate or 'quit' to exit: return with the codex and hopefully find out what the professor is up to as it turns out the venture captain was right to worry rival Gorbic Salmore learned of her duplicity and sought the codex for himself with little time to prepare he dispatched Cheh a captive mimic to subdue
#
# -----------------------------------------------------------------------------------------------
# Snaug_bot:
# <div class="entities" style="line-height: 2.5; direction: ltr">[return with the codex and hopefully find out what the professor is up to as it turns out the venture captain was right to worry rival
# <mark class="entity" style="background: #aef5ef; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Gorbic Salmore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  learned of her duplicity and sought the codex for himself with little time to prepare he dispatched
# <mark class="entity" style="background: #58f549; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Cheh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MOB</span>
# </mark>
#  a captive mimic to subdue] Montrovale in her private classroom and retrieve the book from her Salmore warned the mimic that pathfinders might be on the way and instructed it to be quick about its work
# <mark class="entity" style="background: #58f549; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Cheh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MOB</span>
# </mark>
#  sneaked into her lycanthropic she shouts with joy and rather approaching running than off one stops out of her point she says you have been great before
# <mark class="entity" style="background: #58f549; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Kavoos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MOB</span>
# </mark>
#  is manipulate to pay her in her shuttered as he is known to retrieve the</div>
# Notables:
#    PER(s)	: Gorbic Salmore, Montrovale
#    MOB(s)	: Cheh, Kavoos
# -----------------------------------------------------------------------------------------------
#
#
# Enter seeding text or hit <ENTER> to automate or 'quit' to exit: quit
